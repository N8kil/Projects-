# %%
with open('final_pipeline.pkl',"rb") as f:
    pipe=pickle.load(f)

# %%
test= pd.read_excel('test_set_PCR_3.xlsx')
test.drop("ID",inplace=True,axis=1) 
q=pipe.predict(test)

# %%
y_pred=pd.DataFrame({'pred_RelapseFreeSurvival':q})
data_pred=pd.merge(y_pred,df22,left_index=True,right_index=True)
id = data_pred.pop('ID')
data_pred.insert(0,'ID',id)
data_pred.head()
# Out:
#           ID  pred_RelapseFreeSurvival        Age  ER  PgR  HER2  \
# 0  TRG002448                 42.324896  72.700890   1    1     0
# 1  TRG002918                 30.634217  52.400000   0    0     0
# 2  TRG002714                 60.930824  43.682409   1    1     0
# 3  TRG002399                 59.221558  48.000000   1    1     1
# 4  TRG002948                 58.736938  58.500000   1    0     1
#
#    TrippleNegative  ChemoGrade  Proliferation  HistologyType  ...  \
# 0                0           2              1              2  ...
# 1                1           2              1              1  ...
# 2                0           3              2              1  ...
# 3                0           2              1              1  ...
# 4                0           3              2              1  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                       0.490368
# 1                                       0.434567
# ...

# %%
data_pred.to_excel('FinalTestRFS.xlsx',index=False)
